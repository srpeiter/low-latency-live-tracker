# %% [markdown]
# Let's see if I understand the problem:
#
# > An asset listed on a exchange is prone to sharp price fluctuations within a short time scale. This has various reasons such as release of big news, sudden large purchase or release of that asset. These large fluctuations often occur on large exchanges like **Binance** etc.
#
# > Now if a market maker like Fourstroke is trading this asset at a speed slower than the timescale of the fluctuations, the risk of not noticing this rapid change in price and miss on the opportunity to capitalize on this or even worse: they risk of being arbitraged by other market maker
#
# > The task is to develop an application to track these sharp price fluctuations and warn the trading system such that it can adjust it bid-ask price on time!
#
# > Basically, create a program that measures the volatility of a given asset with high resolution

# %% [markdown]
# Let's concretize this problem is a bit.:
# - We will be using data from binance crypto exchange. Later we will generalize this to different exchanges
#
# - Let's first start simple and check the internet for a library which does this for us. Then we can move on optimize stuff.
#
# - Found an interesting library in python that basically acts as a single wrapper around APIs of different crypto exchanges: ccxt (https://github.com/ccxt/ccxt)

# %% [markdown]
# Do I need credentials to make use of binance API? Let's first understand how the ccxt API works

# %%
import ccxt
import pandas as pd

# %%
print(ccxt.exchanges)

# %% [markdown]
# The BTC/USDT Coin-M future is listed on https://www.binance.com/en/delivery/btcusd_perpetual

# %%
coinm = ccxt.binancecoinm()
markets = coinm.load_markets()
print(coinm.id, markets)

# %%
pd.DataFrame(ccxt.binancecoinm().fetch_order_book('BTC/USD'))

# %% [markdown]
# We want to get a continious stream of data. The standard CCXT library does not provide this. The pro version does, but we have to pay for it. Let's check for other libraries which do support websocket data stream.
# Found a python-binance-connector library, which automatically opens up a websocket connection for us, sends a request to the server and retrieves the data (https://github.com/binance/binance-futures-connector-python).

# %%
import time
import logging
from binance.lib.utils import config_logging
from binance.websocket.cm_futures.websocket_client import CMFuturesWebsocketClient

config_logging(logging, logging.DEBUG)


def message_handler(message):
    print(message)


my_client = CMFuturesWebsocketClient()
my_client.start()

test = my_client.book_ticker(
    id=13,
    callback=message_handler,
    symbol="btcusd_perp"
)

time.sleep(5)

logging.debug("closing ws connection")
my_client.stop()
# Out:
# INFO:root:Connection with URL: wss://dstream.binance.com/ws
# INFO:root:Start to connect....
# INFO:root:Server connected
# INFO:root:Sending message to Server: b'{"method": "SUBSCRIBE", "params": ["btcusd_perp@bookTicker"], "id": 13}'
# {'id': 13, 'result': None}
# {'u': 505912277598, 'e': 'bookTicker', 's': 'BTCUSD_PERP', 'ps': 'BTCUSD', 'b': '20549.2', 'B': '3157', 'a': '20549.3', 'A': '4817', 'T': 1657563443621, 'E': 1657563443628}
# {'u': 505912277688, 'e': 'bookTicker', 's': 'BTCUSD_PERP', 'ps': 'BTCUSD', 'b': '20549.2', 'B': '3157', 'a': '20549.3', 'A': '4549', 'T': 1657563443637, 'E': 1657563443645}
# {'u': 505912277779, 'e': 'bookTicker', 's': 'BTCUSD_PERP', 'ps': 'BTCUSD', 'b': '20549.2', 'B': '3157', 'a': '20549.3', 'A': '4784', 'T': 1657563443651, 'E': 1657563443660}
# {'u': 505912278037, 'e': 'bookTicker', 's': 'BTCUSD_PERP', 'ps': 'BTCUSD', 'b': '20549.2', 'B': '3157', 'a': '20549.3', 'A': '4549', 'T': 1657563443703, 'E': 1657563443707}
# {'u': 505912278071, 'e': 'bookTicker', 's': 'BTCUSD_PERP', 'ps': 'BTCUSD', 'b': '20549.2', 'B': '3157', 'a': '20549.3', 'A': '4763', 'T': 1657563443710, 'E': 1657563443717}
# {'u': 505912278198, 'e': 'bookTicker', 's': 'BTCUSD_PERP', 'ps': 'BTCUSD', 'b': '20549.2', 'B': '3157', 'a': '20549.3', 'A': '4863', 'T': 1657563443743, 'E': 1657563443747}
# {'u': 505912278208, 'e': 'bookTicker', 's': 'BTCUSD_PERP', 'ps': 'BTCUSD', 'b': '20549.2', 'B': '2957', 'a': '20549.3', 'A': '4863', 'T': 1657563443745, 'E': 1657563443750}
# {'u': 505912278209, 'e': 'bookTicker', 's': 'BTCUSD_PERP', 'ps': 'BTCUSD', 'b': '20549.2', 'B': '
 'e': 'bookTicker', 's': 'BTCUSD_PERP', 'ps': 'BTCUSD', 'b': '20549.2', 'B': '1907', 'a': '20549.3', 'A': '7156', 'T': 1657563446949, 'E': 1657563446958}
# {'u': 505912298168, 'e': 'bookTicker', 's': 'BTCUSD_PERP', 'ps': 'BTCUSD', 'b': '20549.2', 'B': '1907', 'a': '20549.3', 'A': '7367', 'T': 1657563446959, 'E': 1657563446967}
# {'u': 505912298462, 'e': 'bookTicker', 's': 'BTCUSD_PERP', 'ps': 'BTCUSD', 'b': '20549.2', 'B': '1907', 'a': '20549.3', 'A': '7617', 'T': 1657563446975, 'E': 1657563446983}
# {'u': 505912298540, 'e': 'bookTicker', 's': 'BTCUSD_PERP', 'ps': 'BTCUSD', 'b': '20549.2', 'B': '1907', 'a': '20549.3', 'A': '7367', 'T': 1657563446981, 'E': 1657563446985}
# {'u': 505912298622, 'e': 'bookTicker', 's': 'BTCUSD_PERP', 'ps': 'BTCUSD', 'b': '20549.2', 'B': '1857', 'a': '20549.3', 'A': '7367', 'T': 1657563446986, 'E': 1657563446994}
# {'u': 505912298948, 'e': 'bookTicker', 's': 'BTCUSD_PERP', 'ps': 'BTCUSD', 'b': '20549.2', 'B': '1857', 'a': '20549.3', 'A': '7486', 'T': 1657563447012, 'E': 1657563447021}
# {'u': 505912298970, 'e': 'bookTicker', 's': 'BTCUSD_PERP', 'ps': 'BTCUSD', 'b': '20549.2', 'B': '1857', 'a': '20549.3', 'A': '7585', 'T': 1657563447013, 'E': 1657563447021}
# {'u': 505912299167, 'e': 'bookTicker', 's': 'BTCUSD_PERP', 'ps': 'BTCUSD', 'b': '20549.2', 'B': '1857', 'a': '20549.3', 'A': '7734', 'T': 1657563447027, 'E': 1657563447033}
# {'u': 505912299283, 'e': 'bookTicker', 's': 'BTCUSD_PERP', 'ps': 'BTCUSD', 'b': '20549.2', 'B': '1857', 'a': '20549.3', 'A': '7898', 'T': 1657563447033, 'E': 1657563447039}
# {'u': 505912299402, 'e': 'bookTicker', 's': 'BTCUSD_PERP', 'ps': 'BTCUSD', 'b': '20549.2', 'B': '1857', 'a': '20549.3', 'A': '8148', 'T': 1657563447039, 'E': 1657563447048}
# {'u': 505912299495, 'e': 'bookTicker', 's': 'BTCUSD_PERP', 'ps': 'BTCUSD', 'b': '20549.2', 'B': '1857', 'a': '20549.3', 'A': '7898', 'T': 1657563447046, 'E': 1657563447054}
# {'u': 505912299808, 'e': 'bookTicker', 's': 'BTCUSD_PERP', 'ps': 'BTCUSD', 'b': '20549.2', 'B': '1857', 'a': '20549.3', 'A': '7919', 'T': 1657563447071, 'E': 1657563447079}

# %% [markdown]
# Ok, now we have managed to get a realtime stream of data of the corresponding symbol into our notebook. Now we need to compute the volatility within a millisecond. Let's see how we can access the data printed in the console.
#
# Ok, digged into the source code of the binance-future-connector library and apparently this data is coming from a thread: Complicated stuff. I somehow dont seem how I can access to the thread. We can immediately catch the data printed at the output, but that will a overhead.
#
# Let's try another library: unicorn binance library

# %%
from unicorn_binance_websocket_api.manager import BinanceWebSocketApiManager
import logging
import os
import time
import threading, queue

import json
from collections import deque
import numpy as np
logging.getLogger("unicorn_binance_websocket_api")
# Out:
# <Logger unicorn_binance_websocket_api (WARNING)>

# %% [markdown]
# The way this works: there is a streambuffer which is being supplied with data from the binance server. If we don't get data from the buffer, the buffer will increase and take up memory.
# Let's see if we can calculate the volatility from streamed data

# %%
def print_stream_data_from_stream_buffer(binance_websocket_api_manager,dataque, volatility_que):
    oper = proc_Data(window = 200)
    while True:
#         print('streamsize:',  binance_websocket_api_manager.get_stream_buffer_length())
        if binance_websocket_api_manager.is_manager_stopping():
            exit(0)
        data_from_stream_buffer = binance_websocket_api_manager.pop_stream_data_from_stream_buffer()
        if data_from_stream_buffer is False:
            time.sleep(0.01)
        else:
            try:
                data_dict = json.loads(data_from_stream_buffer)
                t = time.time()
                data_volatility = oper.calc_volatility(data_dict)
                if data_volatility is not None:
                    volatility_que.append(data_volatility)
                dataque.append([data_dict['data']['T'],data_dict['data']['a']])
#                 print (volatility_que)
#                 print ("time: ", time.time()-t)
            except KeyError:
                pass

            
def start_websocket_listener(dataque, volatility_que):
    # create instance of BinanceWebSocketApiManager and 
    #provide the function for stream processing
    binance_websocket_api_manager = BinanceWebSocketApiManager(
        exchange="binance.com-coin_futures")
    # create streams
    bookTicker_arr_stream_id = binance_websocket_api_manager.create_stream(
        channels="bookTicker",markets='btcusd_perp')
    
    print('max streamsize:',  binance_websocket_api_manager.get_stream_buffer_maxlen())
    # start one worker process (or more) to move the 
    #received stream_data from the stream_buffer to a print function
    worker_thread = threading.Thread(target=print_stream_data_from_stream_buffer, 
                                     args=(binance_websocket_api_manager,dataque, volatility_que))
    worker_thread.start()

class proc_Data():
    
    def __init__(self, window = 200):
        
        self.buffer = deque()
        self.window = window
        self.flag = False
        self.dt = 0
        self.ti = []
        
    def construct_window(self, data_dict):
        if self.flag:
            self.ti.pop(0)
            self.buffer.popleft()
            self.dt = np.sum(np.diff(np.array(self.ti)))
            self.flag = False
        
        if (self.dt <= self.window):
            self.ti.append(data_dict['data']['T'])
            self.buffer.append([data_dict['data']['T'],
                               data_dict['data']['b'],
                               data_dict['data']['a']])
        
            self.dt = np.sum(np.diff(np.array(self.ti)))
            
        else:
            self.flag = True
            rol_window = np.array(self.buffer,dtype=np.float64)
#             print (np.sum(np.diff(rol_window[:,0])))
#             print (self.buffer)
            return rol_window
      
        
    def calc_volatility(self, data_dict):
        
        rlw = self.construct_window(data_dict) 
        if rlw is None:
            pass
        
        else:
            _,idx = np.unique(rlw[:,0], return_index = True)
            _rlw = np.zeros((len(idx),2))
            _rlw[:,0] = rlw[idx,0]
            _rlw[:,1] = (rlw[idx,1] + rlw[idx,2]) / 2
            diff_arr = np.diff(_rlw,axis=0)
#             print('diff: ',diff_arr)
            volt_t = np.sum(np.abs(diff_arr[:,1]/_rlw[1:,1])/diff_arr[:,0])/len(diff_arr)
#             print('volt',volt)
            return [_rlw[-1,0], volt_t]
       
dataque = deque()#queue.Queue()
volatility_que = deque()
start_websocket_listener(dataque, volatility_que)
# Out:
# max streamsize: None

# %% [markdown]
# Ok, what have we done till so far?
#
# - I am able to get orderbook data from the server. One thing I notice, is that the server bid/ask prices obtained with the current API does not match the pric of the future in our browser; why is that?
#
# - I implemented a rolling window that calculated the volatility of a given asset. The window size is adjustable
#
# - I notice that there are multiple orders that occurred at the same transaction time, but also several orders that contain the same price. I remove those that happened at the same time, because those have the same price and therefore do not add any new information
#
# - Lastly, when I remove all the print statement, my code is able to calculate the volatility in below a millisecond.
#
# - Let's see if we can plot this streaming data

# %% [markdown]
# The volatility metric is calculated with <br>
# midprice = m(t) <br>
# askprice = a(t) <br>
# bidprice = b(t) <br>
# $\rm m(t)  = \frac{b(t) + a(t)}{2}$<br>
# $\rm Volatility = \frac{1}{n} \sum_t \bigl|\frac{\frac{m(t) - m(t-1)}{m(t)}}{dt}\bigr| $

# %%
import dash
from dash import html
from dash import dcc
from dash.dependencies import Input, Output
import plotly
import plotly.graph_objs as go
import pandas as pd

class display_bookTicker():
    
    def __init__(self,datastream, voltstream):
        self.stream = datastream
        self.vstream = voltstream
        self.t_stamp = deque()
        self.volt_t_stamp = deque()
        self.price = deque()
        
        self.app = dash.Dash()
        self.app.layout = html.Div([
        html.Div([
            html.H1(
                children = "COIN-M BTCUSDT (perp) LIVE TRACKING",
                style = {
                    'color': '#d486f0',
                    'backgroundColor': "#18191c",
                }
            )
        ], className = 'row'),
        html.Div([ ### FIGURES Divs
            html.Div([
                dcc.Graph(id = 'fig_1' ,),
                dcc.Interval(id = 'fig_1_update' ,interval=1200 , n_intervals = 0)
            ], className = 'pricefig'),
            html.Div([
                dcc.Graph(id = 'fig_2' ),
                dcc.Interval(id = 'fig_2_update', interval= 1200, n_intervals = 0)
            ], className = 'voltfig')
        ], className = 'row')])
        self.app.callback(
            [Output('fig_1', 'figure'),Output('fig_2', 'figure')],
            Input('fig_1_update', 'n_intervals'))(self.update_graph)
    
    def update_graph(self, n):
        _tempdata = np.array(self.stream, dtype = np.float64)
        _timest = pd.Series(_tempdata[:,0])*1e-3
        timest = pd.to_datetime(_timest,unit='s')
        
        fig_1 = go.Figure(
            data = go.Scatter(
            x = timest,
            y = _tempdata[:,1], name = 'Price',showlegend = True))
        
        fig_1.update_layout(title = 'Ask price', yaxis=dict(tickformat=".1f") )
        
        _tempvoltdata = np.array(self.vstream, dtype = np.float64)
        _timestvolt = pd.Series(_tempvoltdata[:,0])*1e-3
        timestvolt = pd.to_datetime(_timestvolt,unit='s')
        
        fig_2 = go.Figure(
            data = go.Scatter(
            x = timestvolt,
            y = _tempvoltdata[:,1]*1e5, name = 'Volatility',showlegend = True,
            marker = dict(color='red'),))
        
        fig_2.update_layout(title = 'Volatility',yaxis=dict(tickformat=".2f",title='Percentage Change/s'))
        
        return [fig_1,fig_2]

if __name__ == '__main__':
    show_ticker = display_bookTicker(dataque,volatility_que)
    show_ticker.app.run_server(host='10.164.0.4', port='8050')
# Out:
# Dash is running on http://10.164.0.4:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://10.164.0.4:8050/ (Press CTRL+C to quit)
# 92.110.1.169 - - [12/Jul/2022 01:03:33] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:03:35] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:03:35] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:03:36] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:03:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:03:38] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:03:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:03:41] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:03:42] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:03:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:03:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:03:46] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:03:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:03:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:03:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:03:50] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:03:52] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:03:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:03:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:03:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:03:56] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:03:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:03:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:04:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:04:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:04:02] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:04:04] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:04:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:04:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:04:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:04:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:04:10] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:04:11] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:04:12] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:04:13] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:04:14] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:04:16] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:04:17] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:04:18] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:04:19] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:04:20] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:04:22] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:04:23] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:04:24] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:04:25] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:04:26] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:04:28] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:04:29] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:04:30] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:04:31] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:04:32] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:04:34] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:04:35] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:04:36] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:04:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:04:38] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:04:40] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:04:41] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:04:42] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:04:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:04:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:04:46] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:04:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:04:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:04:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:04:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:04:52] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:04:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:04:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:04:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:04:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:04:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:04:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:05:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:05:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:05:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:05:04] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:05:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:05:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:05:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:05:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:05:09] "GET / HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:05:10] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:05:10] "GET /_dash-layout HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:05:10] "GET /_dash-dependencies HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:05:10] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 304 -
# 92.110.1.169 - - [12/Jul/2022 01:05:10] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 304 -
# 92.110.1.169 - - [12/Jul/2022 01:05:10] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:05:11] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:05:12] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:05:12] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:05:13] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:05:13] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:05
12] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:10:14] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:10:14] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:10:16] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:10:17] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:10:18] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:10:20] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:10:21] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:10:22] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:10:24] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:10:25] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:10:25] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:10:28] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:10:28] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:10:30] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:10:31] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:10:33] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:10:33] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:10:35] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:10:36] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:10:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:10:38] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:10:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:10:42] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:10:42] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:10:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:10:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:10:45] "POST /_dash-update-component HTTP/1.1" 200 -
# BinanceWebSocketApiSocket.start_socket(22ee214efd22-9537-b0b9-f74b-901e449f, ['bookTicker'], ['btcusd_perp']) - Exception ConnectionClosed - error_msg: sent 1011 (unexpected error) keepalive ping timeout; no close frame received
# BinanceWebSocketApiManager.stream_is_crashing(22ee214efd22-9537-b0b9-f74b-901e449f)
# 92.110.1.169 - - [12/Jul/2022 01:10:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:10:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:10:50] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:10:52] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:10:52] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:10:52] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:10:56] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:10:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:10:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:10:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:11:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:11:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:11:04] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:11:04] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:11:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:11:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:11:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:11:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:11:11] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:11:12] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:11:13] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:11:13] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:11:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:11:16] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:11:18] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:11:20] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:11:21] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:11:21] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:11:23] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:11:23] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:11:26] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:11:27] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:11:28] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:11:29] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:11:29] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:11:31] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:11:33] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:11:34] "GET / HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:11:34] "GET /_dash-layout HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:11:34] "GET /_dash-dependencies HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:11:34] "GET /_favicon.ico?v=2.5.1 HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:11:35] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:11:35] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:11:35] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:11:35] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:11:36] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:11:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:11:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:11:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:11:40] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:11:41] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:11:41] "POST /_dash-update-component HTTP/1.1" 200 -
# 92.110.1.169 - - [12/Jul/2022 01:11:42] "POST /_dash-update-component HTTP/1.1" 200 -

# %% [markdown]
# # Testing

# %%
for thread in threading.enumerate(): 
    print(thread.name)
# Out:
# MainThread
# IOPub
# Heartbeat
# Thread-3
# Thread-4
# Control
# IPythonHistorySavingThread
# Thread-2

# %%
import dash
from dash import html
from dash import dcc
from dash.dependencies import Input, Output
import plotly
import plotly.graph_objs as go
import pandas as pd
class display_bookTicker():
    
    def __init__(self,datastream, voltstream):
        self.stream = datastream
        self.vstream = voltstream
        self.t_stamp = deque()
        self.volt_t_stamp = deque()
        self.price = deque()

        
        self.app = dash.Dash()
        self.app.layout = html.Div(
            [
                dcc.Graph(id = 'live-graph', animate = True),
                dcc.Interval(
                    id = 'graph-update',
                    interval = 1200,
                    n_intervals = 0
                )
            ]
            )
        self.app.callback(
            Output('live-graph', 'figure'),
            [Input('graph-update', 'n_intervals')])(self.update_graph)
    
    def update_graph(self, n):
        _tempdata = np.array(self.stream, dtype = np.float64)
        _timest = pd.Series(_tempdata[:,0])*1e-3
        timest = pd.to_datetime(_timest,unit='s')

        data = go.Scatter(
            x = timest,
            y = _tempdata[:,1],
            name ='Scatter',
            mode = 'lines+markers')
        
        data2 = go.Scatter(
            x = timest,
            y = _tempdata[:,1],
            name ='Scatter',
            mode = 'lines+markers')

        return {'data': [data,data2],
                'layout': go.Layout(xaxis=dict(range=[timest.min(), timest.max() + pd.to_timedelta(2,unit='s')]))}


if __name__ == '__main__':
    show_ticker = display_bookTicker(dataque,volatility_que)
    show_ticker.app.run_server(host='10.164.0.4', port='8050')
